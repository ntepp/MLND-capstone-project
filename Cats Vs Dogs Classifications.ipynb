# %% [markdown]
# ### Machine Learning Nanodegree
# ### Capstone Project
# ### Project: Dogs vs Cats Classification
# .....

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob
from PIL import Image
from sklearn.model_selection import train_test_split
import cv2         
import matplotlib.pyplot as plt   
# %matplotlib inline 

# load list of dog names
X = [item[:] for item in sorted(glob("data/*"))]
test_image = [item[:] for item in sorted(glob("2/*"))]
# label 0 for cat
y = np.zeros(12500) 
# label 1 for dog
y = np.append(y, np.ones(12500))
X_train_files, X_test_files, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
# print statistics about the dataset
print('There are %d total dog and cats.' % len(X))
print('Total Size of training %d.' % len(X_train_files))
print('Total Size of testing %d.' % len(X_test_files))
print('Total Size of valitation %d.' % len(test_image))
# Out:
# Using TensorFlow backend.
# There are 25000 total dog and cats.
# Total Size of training 20000.
# Total Size of testing 5000.
# Total Size of valitation 0.

# %% [markdown]
# ### Helper Functions For Loading Data

# %%
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
# show an images
def print_images(image):
    img = cv2.imread(image)
    img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
    #img = cv2.resize(img, (255, 255), interpolation = cv2.INTER_CUBIC)
    plt.imshow(img)

print_images(X_train_files[5])

# %%
print_images(X_train_files[8])

# %% [markdown]
# ### Data Pre-processing
